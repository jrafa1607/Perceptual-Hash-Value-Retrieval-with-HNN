# %%
#Import das Bibliotecas
#Download da Lib para Calcular o D-Hash https://pypi.org/project/ImageHash/

import os
import cv2
import hashlib
import imagehash
import matplotlib as mpl

from PIL import Image
from scipy.spatial import *
from matplotlib import pyplot as plot

# %%
#Path Definition
path = 'D:/Google Drive/Github/HNN-to-Content-Based-Hash-Retrieval/Image Database/DevicesDatabase'

# %%
#Definição da Imagem Alterada
image_name = str(input("Nome do Arquivo de Imagem Alterada: ") + "." + input("Extensão da Imagem Alterada: "))
